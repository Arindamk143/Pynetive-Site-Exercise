# %%
import numpy as np

# %%
Arindam = np.array([[10,20,30,100],
                    [50,143,90,99]])
Puja = np.array([[40,50,60,1000],
               [500,143,900,75]])

# %%
Arindam
# Out:
# array([[ 10,  20,  30, 100],
#        [ 50, 143,  90,  99]])

# %%
Puja
# Out:
# array([[  40,   50,   60, 1000],
#        [ 500,  143,  900,   75]])

# %%
import matplotlib.pylab as plt
plt.plot(Arindam,Puja, linewidth = 3, color = 'b', marker='o',markerfacecolor='r')
plt.title("Love Data")
plt.xlabel("Arindam")
plt.ylabel("Puja")
plt.grid(True,linewidth = 1 , linestyle = '--')
plt.show()
